# %%
import statsmodels.api as sm
from scipy.stats import norm
import pylab
import pandas as pd

# %%
path_to_data = "/Users/erotokritosskordilis/Dropbox/ProvostAward2024/MonetaryPolicy_AI/train_data.csv"

df = pd.read_csv(path_to_data)
df.rename(columns={
    'Inflation 1 Implicit GDP price deflator (%)': "inflation_1", 
    "Inflation 2 PCE Index (%)": "inflation_2",
    "FEDFUNDS (%)": "fedfunds",
    "Output GAP (%)": "output_gap"
    }, inplace=True
)
print(df.columns)

my_data = df["GDP (Billion $)"]
sm.qqplot(my_data, line='45')
pylab.show()
# Out:
# Index(['Frequency: Quarterly observation_date', 'inflation_1', 'inflation_2',
#        'fedfunds', 'output_gap', 'GDP (Billion $)',
#        'Potential GDP (Billion $)'],
#       dtype='object')
